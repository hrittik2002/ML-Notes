# %% [markdown]
# <a href="https://colab.research.google.com/github/hrittik2002/ML-Notes/blob/main/python/iterator_and_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Python Iterators

# %% [markdown]
# ## 1.1. What is Iteration
#
# Iteration is a general term for taking each item of something, one after another. Any time you use a loop, explicit or implicit, to go over a group of items, that is iteration.

# %%
# Example
num = [1,2,3]

for i in num:
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## 1.2. What is Iterator
#
# - An iterator is a object that allows the programmer to traverse through a sequence of data **without having to store the entire data in the memory**.
#
# - Iterator is that object due to which iteration is possible. Interally when we are running a loop, there is an iterator object that fetch the items one by one and give it to loop.
#
# - The Best thing about Iterator is it loads one item in the memory at a time, then perform all the operations then remove that item from the memory, then loads the next item in the memory. Due to this it is much memory efficient.
#
# - Every iterator contains **an iter function and a next function**.

# %%
# Lets say we have to print the multiplication by 2 of all the first 100 natural numbers.
import sys

# without iterator
L = [x for x in range(1,100)]

# for i in L:
#   print(i*2)

# how much memory occupied
sys.getsizeof(L) # bytes
# Out:
# 920

# %%
# with iterator
x = range(1,100)

# for i in x:
#   print(i*2)

# how much memory occupied
sys.getsizeof(x) # bytes
# Out:
# 48

# %% [markdown]
# Here,
# - when we are using list L, here in the memory we are loading all the items at once, so it is taking 920 bytes memory.
# - In the secound case, we are using range (internally iterator), here 1 item is loading the memory at a time so it is taking 48 bytes memory.

# %% [markdown]
# #  1.3. What is Iterable
#
# - Iterable is an object, which one can iterate over. Means any obeject in Python in which we can run loop and get items of that object one by one then it is iterable.
#
# - Note for iterator the items loads in the memory 1 at a time. But here it is not the case, any item where we can apply loop is iterable.
#
# - Means list, dictionary, set, tuple, range all of the 5are iterable. But it we talk about iterator only range is iterator.
#
# - Every iterator is iterable. But all iterable are not iterator.
#
# - Iterable Object generates an iterator when passed to i**ter() methods**.
#
# - When we run loop over a iterable interally it uses the iter() method to generate iterator.

# %%
# Example

L = [1,2,3]

print(type(L))
# Here List L is a iterable

print(type(iter(L)))
# Here List L is a iterator
# Out:
# <class 'list'>
# <class 'list_iterator'>

# %% [markdown]
# ## 1.4. iter() and next() function
#
# - Every iterable contains a iter() method

# %%
# Example

L = [1,2,3]

print(type(L)) # Here List L is a iterable

dir(L) # To verify check L must contain __iter__ method
# Out:
# <class 'list'>
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# - Every iterator contains a iter function and a next function

# %%
# Example

L = [1,2,3]

print(type(L))
# Here List L is a iterable

iterator_obj = iter(L) # we can generate iterator object using __iter__

print(type(iterator_obj))

dir(iterator_obj) # To verify check iterator_obj must contain __iter__ and __next__
# Out:
# <class 'list'>
# <class 'list_iterator'>
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__length_hint__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# - If we pass a iterable object through iter() then we get a iterator object.
#
# - If we pass a iterator object through iter() then we get the same iterator object.
#
# - If we pass a iterator object through next() then we get the next item.

# %%
# Example
L = [1,2,3] # List is a iterable

 # We can generate a iterator when we pass iterable to __iter__ function
iterator_obj = iter(L)
print(iterator_obj)

# If we again pass the iterator object to __iter__ function
print(iter(iterator_obj)) # check the output carefully we are getting the same iterator object

# %%
# we use __next__ function to get the next item
print(next(iterator_obj)) # we get 1
print(next(iterator_obj)) # we get 2
print(next(iterator_obj)) # we get 3
print(next(iterator_obj)) # we get Exception StopIteration
# Out:
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_708/1872135190.py in <cell line: 0>()
#       3 print(next(iterator_obj))
#       4 print(next(iterator_obj))
# ----> 5 print(next(iterator_obj))
#
# StopIteration:

# %% [markdown]
# ## 1.5. How for loop works?

# %%
num = [1,2,3]

for i in num:
  print(i)
# Out:
# 1
# 2
# 3

# %%
# interanlly
num = [1,2,3]

# Step-1 : Fetch the iterator
iter_num = iter(num)

# Step-2 : next
print(next(iter_num))
print(next(iter_num))
print(next(iter_num))
print(next(iter_num)) # running __next__ till we getting StopIteration
# Out:
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_708/3718149269.py in <cell line: 0>()
#       9 print(next(iter_num))
#      10 print(next(iter_num))
# ---> 11 print(next(iter_num))
#
# StopIteration:

# %% [markdown]
# Lets create a custom for loop

# %%
def custom_for_loop(iterable):
  iterator = iter(iterable) # Step-1 : generate iterator
  while True:
    try:
      print(next(iterator)) # Step-2 : get next item till exception
    except StopIteration:
      break

# test it
a = [1,2,3]
custom_for_loop(a)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## 1.6 create custom range() function

# %%
class custom_range: # iterable

  def __init__(self, start, end):
    self.start = start
    self.end = end

  def __iter__(self):
    return custom_range_iterator(self) # return iterator object


class custom_range_iterator: # iterator

  def __init__(self,iterable_obj):
    self.iterable = iterable_obj

  def __iter__(self):
    return self # when we run __iter__ over iterator it return self

  def __next__(self):
    if self.iterable.start >= self.iterable.end:
      raise StopIteration
    current = self.iterable.start
    self.iterable.start += 1
    return current

# %%
for i in custom_range(1,10):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# # 2. Generators
#
# - Python generators are a simple way of creating iterators.
# - Python generators are nothing but a function, where we do yeild instead of return.

# %%
# Example : Lets create a very simple generator
def gen_demo():
  yield "First Statement"
  yield "Second Statement"
  yield "Third Statement"

gen = gen_demo() # Lets call the generator function
print(gen)
# Out:
# <generator object gen_demo at 0x79a7637bc7d0>

# %% [markdown]
# - When we call a generator function it returns a generator object instead of any value.
#
# - Now the specility of this generator object is that we can pass it through next() function. And it will return the value of the yeild. After returning all the yeild it returns StopIteration Exception.

# %%
print(next(gen))
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# First Statement
# Second Statement
# Third Statement
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_5281/2107124985.py in <cell line: 0>()
#       2 print(next(gen))
#       3 print(next(gen))
# ----> 4 print(next(gen))
#
# StopIteration:

# %% [markdown]
# We could have used loop also

# %%
def gen_demo():
  yield "First Statement"
  yield "Second Statement"
  yield "Third Statement"

gen = gen_demo()

for i in gen:
  print(i)
# Out:
# First Statement
# Second Statement
# Third Statement

# %% [markdown]
# - The gen_demo() function is not getting  called when we are running this line
#   ```python
#   gen = gen_demo()
#   ```
#   The gen_demo() function is getting called when we use next() on generator object `gen`
#
# - Now when we are running `next(gen)`, the generator object is loading the value of the 1st yield in memory and returing it just like iterator. After returing it is getting removed from the memory but remmembering up to where it runned before. So that when we will run `next(gen)` again, it will run from there only. This is the biggest difference between yield and return.

# %%
# Example 2

def square(num):
  for i in range(1,num+1):
    yield i**2

gen = square(10)

print(next(gen))
print(next(gen))
# Out:
# 1
# 4

# %%
for i in gen:
  print(i)
# Out:
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %% [markdown]
# It will not run from the start, it will remember up till what it had ran.

# %%
# Example 3 : Range Function with generator
def custom_range(start , end):
  for i in range(start,end):
    yield i

for i in custom_range(1,10):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# ## 2.1. Generator Expression

# %%
# we know the how to create list comprehension
L = [i**2 for i in range(1,10)]

# %%
# it is simplar just we need to put parentisis
gen = (i**2 for i in range(1,10))

for i in gen:
  print(i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# ## 2.2. Benifit of Generators
#
# ### a. Ease of use
# The same code that iterator takes 100lines with the help of generators we can write in 2 lines

# %%
#  Range Function with generator
def custom_range(start , end):
  for i in range(start,end):
    yield i

for i in custom_range(1,10):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# same custom range using iterator
class custom_range: # iterable

  def __init__(self, start, end):
    self.start = start
    self.end = end

  def __iter__(self):
    return custom_range_iterator(self) # return iterator object


class custom_range_iterator: # iterator

  def __init__(self,iterable_obj):
    self.iterable = iterable_obj

  def __iter__(self):
    return self # when we run __iter__ over iterator it return self

  def __next__(self):
    if self.iterable.start >= self.iterable.end:
      raise StopIteration
    current = self.iterable.start
    self.iterable.start += 1
    return current

for i in custom_range(1,10):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# Just compare iterator and generator, for generator we can just write the same thing in 2 lines.

# %% [markdown]
# ### b. Memory Efficient
# A real life example, in deep learning when we need to loop through 10000 of high quality images. If we use numpy array there it will crash our system as it loads full image data set in our memory. But we can easily use generators there.

# %% [markdown]
# ### c. Representing Infinite Streams
#
# Lets say we need infinite no of even numbers

# %%
def all_even():
  n=0
  while True:
    yield n
    n += 2

# %%
even_gen = all_even()
next(even_gen)
next(even_gen)
# Out:
# 2

# %% [markdown]
# ### d. Chaining Generators

# %%
def fibinacci_number(nums):
  x,y = 0,1
  for _ in range(nums):
    x,y = y,x+y
    yield x

def square(nums):
  for num in nums:
    yield num**2

print(sum(square(fibinacci_number(10))))
# Out:
# 4895
